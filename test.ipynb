# %%
import yfinance as yf
df = yf.download("ABBV", period="1y", progress=False, threads=False)
print(df.shape)
print(df.tail())
# Out:
# 1 Failed download:
# - ABBV: No data found for this date range, symbol may be delisted
# (0, 6)
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
import sys, subprocess
import streamlit as st

st.write("Python:", sys.version)
st.write(subprocess.check_output([sys.executable, "-m", "pip", "show", "pandas-datareader"]).decode())
# Out:
# 2026-01-12 15:33:01.914 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-12 15:33:02.712
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/vscode/.local/lib/python3.11/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2026-01-12 15:33:02.713 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-12 15:33:02.715 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-12 15:33:02.716 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-12 15:33:02.722 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-12 15:33:02.729 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# WARNING: Package(s) not found: pandas-datareader
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[1], line 5
#       2 import streamlit as st
#       4 st.write("Python:", sys.version)
# ----> 5 st.write(subprocess.check_output([sys.executable, "-m", "pip", "show", "pandas-datareader"]).decode())
#
# File /usr/local/lib/python3.11/subprocess.py:466, in check_output(timeout, *popenargs, **kwargs)
#     463         empty = b''
#     464     kwargs['input'] = empty
# --> 466 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     467            **kwargs).stdout
#
# File /usr/local/lib/python3.11/subprocess.py:571, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     569     retcode = process.poll()
#     570     if check and retcode:
# --> 571         raise CalledProcessError(retcode, process.args,
#     572                                  output=stdout, stderr=stderr)
#     573 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['/usr/local/bin/python', '-m', 'pip', 'show', 'pandas-datareader']' returned non-zero exit status 1.

# %%
import sys, subprocess

def ensure(pkg):
    subprocess.check_call([sys.executable, "-m", "pip", "install", pkg])

try:
    import pandas_datareader
except ImportError:
    ensure("pandas-datareader==0.10.0")
    import pandas_datareader
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas-datareader==0.10.0
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: lxml in /home/vscode/.local/lib/python3.11/site-packages (from pandas-datareader==0.10.0) (6.0.2)
# Requirement already satisfied: pandas>=0.23 in /home/vscode/.local/lib/python3.11/site-packages (from pandas-datareader==0.10.0) (2.3.3)
# Requirement already satisfied: requests>=2.19.0 in /home/vscode/.local/lib/python3.11/site-packages (from pandas-datareader==0.10.0) (2.31.0)
# Requirement already satisfied: numpy>=1.23.2 in /home/vscode/.local/lib/python3.11/site-packages (from pandas>=0.23->pandas-datareader==0.10.0) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vscode/.local/lib/python3.11/site-packages (from pandas>=0.23->pandas-datareader==0.10.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/vscode/.local/lib/python3.11/site-packages (from pandas>=0.23->pandas-datareader==0.10.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/vscode/.local/lib/python3.11/site-packages (from pandas>=0.23->pandas-datareader==0.10.0) (2025.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/vscode/.local/lib/python3.11/site-packages (from requests>=2.19.0->pandas-datareader==0.10.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/vscode/.local/lib/python3.11/site-packages (from requests>=2.19.0->pandas-datareader==0.10.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vscode/.local/lib/python3.11/site-packages (from requests>=2.19.0->pandas-datareader==0.10.0) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vscode/.local/lib/python3.11/site-packages (from requests>=2.19.0->pandas-datareader==0.10.0) (2026.1.4)
# Requirement already satisfied: six>=1.5 in /home/vscode/.local/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas-datareader==0.10.0) (1.17.0)
# Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 kB 10.1 MB/s eta 0:00:00
# Installing collected packages: pandas-datareader
# Successfully installed pandas-datareader-0.10.0
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip
